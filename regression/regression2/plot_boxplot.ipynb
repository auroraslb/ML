# %%
#Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import BayesianRidge

#Extract data
X = np.load('Xtrain_Regression_Part2.npy')
y = np.load('Ytrain_Regression_Part2.npy')
X_test = np.load('Xtest_Regression_Part2.npy')

list_of_features = ['Column_1','Column_2','Column_3','Column_4','Column_5','Column_6','Column_7','Column_8','Column_9','Column_10','Column_11','Column_12','Column_13','Column_14','Column_15','Column_16','Column_17','Column_18','Column_19','Column_20']
df_raw = pd.DataFrame(X, columns = list_of_features)

# %%
def plot_boxplot(dataframe, feature):
    dataframe.boxplot(column = [feature])
    plt.grid(False)
    plt.show

# %%
plot_boxplot(df_raw, "Column_1")

# %%
plot_boxplot(df_raw, "Column_2")

# %%
plot_boxplot(df_raw, "Column_3")

# %%
plot_boxplot(df_raw, "Column_4")

# %%
plot_boxplot(df_raw, "Column_5")

# %%
plot_boxplot(df_raw, "Column_6")

# %%
plot_boxplot(df_raw, "Column_7")

# %%
plot_boxplot(df_raw, "Column_8")

# %%
plot_boxplot(df_raw, "Column_9")

# %%
plot_boxplot(df_raw, "Column_10")

# %%
plot_boxplot(df_raw, "Column_11")

# %%
plot_boxplot(df_raw, "Column_12")

# %%
plot_boxplot(df_raw, "Column_13")

# %%
plot_boxplot(df_raw, "Column_14")

# %%
plot_boxplot(df_raw, "Column_15")

# %%
plot_boxplot(df_raw, "Column_16")

# %%
plot_boxplot(df_raw, "Column_17")

# %%
plot_boxplot(df_raw, "Column_18")

# %%
plot_boxplot(df_raw, "Column_19")

# %%
plot_boxplot(df_raw, "Column_20")
